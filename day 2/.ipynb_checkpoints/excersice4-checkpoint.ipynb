# %%
#single quotes
a='my name is madushani'
a
# Out:
# 'my name is madushani'

# %%
#double quotes
b='my sister told me:"you have to wash the car"'
b
# Out:
# 'my sister told me:"you have to wash the car"'

# %%
#multiline quotas
c= """these are the subjects:
-python
-statistic
"""
c
# Out:
# 'these are the subjects:\n-python\n-statistic\n'

# %%
#f-string
name="madushani"
print("Hi "+name) 
print(f"Hi {name}!")
# Out:
# Hi madushani
# Hi madushani!

# %%
d='today is sunny'
d
# Out:
# 'today is sunny'

# %%
d[0:2]+d[-2:]
# Out:
# 'tony'

# %%
'today'.upper()
# Out:
# 'TODAY'

# %%
d[:5].upper()
# Out:
# 'TODAY'

# %%
d[-5:].lower()
# Out:
# 'sunny'
