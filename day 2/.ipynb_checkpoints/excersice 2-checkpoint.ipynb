# %%
maxdistance =20
temperature = 30.5
greet_ing = "hello"
isRaining = True

# %% [markdown]
# 1st_value-> value1
# Total$Amount-> total_amount
# calcNum-> calc_num
# Data-Entry-> data_entr

# %%
float(maxdistance)
# Out:
# 20.0

# %%
int(temperature)
# Out:
# 30

# %%
str(temperature)
# Out:
# '30.5'

# %%
float(temperature)
# Out:
# 30.5

# %%
type(maxdistance)
# Out:
# int

# %%
type(temperature)
# Out:
# float

# %%
type(greet_ing)
# Out:
# str

# %%
type(isRaining)
# Out:
# bool
