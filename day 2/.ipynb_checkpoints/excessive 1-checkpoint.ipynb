# %%
if 10>5:  #print wenne na mokada print ekata psse tab eka type krala space thiynna one
print ("ten is bigger than five")
print ("today is sunny")
# Out:
#   Cell In[13], line 2
#     print ("ten is bigger than five")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
if 10>5:
    print ("ten is bigger than five")
    print ("today is sunny")
# Out:
# ten is bigger than five
# today is sunny

# %%
if 10>50:       #print wenne na mkda 10 podi 50ta wada
    print ("ten is bigger than five")
    print ("today is sunny")

# %%
if 10>50: #print wenne yata eka withrai rule mulata gattha nisa
    print ("ten is bigger than five")
print ("today is sunny")
# Out:
# today is sunny

# %%
if 10>50:
    print ("ten is bigger than five")
else:
    print("it's lower")
    print ("today is sunny")
# Out:
# it's lower
# today is sunny

# %%
def sum(a,b): #: me symbole eka danna one
    result = a+b  
    return result #WE RETURN the "RESULT" variables

# %%
sum(10,20)
# Out:
# 30

# %%
sum("mike","elisa")
# Out:
# 'mikeelisa'

# %%
sum("mike",50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 sum("mike",50)
#
# Cell In[21], line 2, in sum(a, b)
#       1 def sum(a,b): #: me symbole eka danna one
# ----> 2     result = a+b
#       3     return result
#
# TypeError: can only concatenate str (not "int") to str

# %%
"MIKE"*10
# Out:
# 'MIKEMIKEMIKEMIKEMIKEMIKEMIKEMIKEMIKEMIKE'

# %%
def sum(a,b): #double qouats dalath comments danna puluwn
    """
    this function recevies two values that are summed together
    """
    result = a+b  
    return result

# %%
##kernel ghin restart kernel runup to selected cell dunnama one cell eka select krala eka aluthin krapu changes withrai save wenne. 
#weradunama eka krnna puluwn

# %%
age=30 # variable definition #you cant start a variable name with  number

# %%
Age =20 # case sensitive capital simple balanwa

# %%
age
# Out:
# 30

# %%
Age
# Out:
# 20

# %%
building1 ="Church"

# %%
building1_name = "church"
building1_height = 100 
                           #same name thiyanna ba

building2_name = "stadium"
building2_height = 200

        
building1_name = "church"#sanke syntax
building1Name = "church"# #canal syntax

# %%
age = 40 # Integers
age= 40.5 #float
age = "40" #Strings (onema deyak double quotes athule nam)
Name = True #Booleans true or false

# %%
type(Name)  #type eken onema variable ekaka type eka hoyaganna puluwn
# Out:
# bool

# %%
type(3>5)
# Out:
# bool

# %%
d = str(Name)
type (d)
# Out:
# str

# %%
d
# Out:
# 'True'

# %%
s= "20"
s+s
# Out:
# '2020'

# %%
int(s)+int(s)     #answer dekak enne
# Out:
# 40

# %%
a =10
b= "julie"
c=True
d = 3.5

# %%
#start with a lower case
#underscore dnne wachana dekak combine kranawanm, number combine kranwanm one na
#ThisIsAString meka weradi this_is_a_string meka hari

# %%
float(a)  # intiger or one ekak eke type eka convert kranna one unama one eke eka dala brackets danna thynne
# Out:
# 10.0
