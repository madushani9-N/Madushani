# %%
def greet (name):
    name = name.upper()
    print(f"hello {name}")

# %%
greet ("alice")
# Out:
# hello ALICE

# %%
employee ="salim"
greet (employee)
# Out:
# hello SALIM

# %%
def calculate_area(width, height):
    return width * height
    print(calculate_area)

# %%
calculate_area(3,5)
# Out:
# 15

# %%
def introduce (name,age):
    print(f"my name is {name}  and im {age} years old")

# %%
introduce("madushani",25)
# Out:
# my name is madushani  and im 25 years old

# %%
my_list =[1,2,3,4,5]

# %%
my_list[-1]   # list eke 5 ganna one nam
# Out:
# 5

# %%
def first_and_last(1):
    return 1[0],1[-1]  #aga and mula value ganna
    first_and_last(my_list)
# Out:
#   Cell In[51], line 1
#     def first_and_last(1):
#                        ^
# SyntaxError: invalid syntax

# %%
# !pip install numpy

# %%
import numpy

# %%
dir(numpy)
# Out:
# ['False_',
#  'ScalarType',
#  'True_',
#  '_CopyMode',
#  '_NoValue',
#  '__NUMPY_SETUP__',
#  '__all__',
#  '__array_api_version__',
#  '__array_namespace_info__',
#  '__builtins__',
#  '__cached__',
#  '__config__',
#  '__dir__',
#  '__doc__',
#  '__expired_attributes__',
#  '__file__',
#  '__former_attrs__',
#  '__future_scalars__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__numpy_submodules__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_array_api_info',
#  '_core',
#  '_distributor_init',
#  '_expired_attrs_2_0',
#  '_globals',
#  '_int_extended_msg',
#  '_mat',
#  '_msg',
#  '_pyinstaller_hooks_dir',
#  '_pytesttester',
#  '_specific_msg',
#  '_type_info',
#  '_typing',
#  '_utils',
#  'abs',
#  'absolute',
#  'acos',
#  'acosh',
#  'add',
#  'all',
#  'allclose',
#  'amax',
#  'amin',
#  'angle',
#  'any',
#  'append',
#  'apply_along_axis',
#  'apply_over_axes',
#  'arange',
#  'arccos',
#  'arccosh',
#  'arcsin',
#  'arcsinh',
# ...

# %%
numpy.arange(start=100, stop=200,step=33)
# Out:
# array([100, 133, 166, 199])

# %%
from numpy import arange

# %%
arange(start=100, stop=200,step=33)  #import krata psse aith numpy type krnna one na
# Out:
# array([100, 133, 166, 199])

# %% [markdown]
# # exercise 1

# %%
import math

# %%
math.sqrt(1024)
# Out:
# 32.0

# %%
import datetime as dt

# %%
now= dt.datetime.now()
now
# Out:
# datetime.datetime(2026, 2, 18, 9, 56, 16, 680884)

# %%
now.strftime("%d/%m/%y %H:%m")
# Out:
# '18/02/26 09:02'

# %% [markdown]
# # exercise 2

# %%
import random   #to generate a random number

# %%
random.randint(100,200)
# Out:
# 158
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %% [markdown]
# # exercise 3

# %%
# !pip install requests  #website ekaka thiyana data files downlod kraganna

# %%
url ="https://www.kaggle.com/datasets?fileType=csv"      #methana url eka danna http walin patan ganna

# %%
import requests

requests.get(url)
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '\r\n\r\n<!DOCTYPE html>\r\n<html lang="en">\r\n\r\n<head>\r\n  <title>Find Open Datasets and Machine Learning Projects | Kaggle</title>\r\n  <meta charset="utf-8" />\r\n    <meta name="robots" content="index, follow" />\r\n  <meta name="description" content="Download Open Datasets on 1000s of Projects &#x2B; Share Projects on One Platform. Explore Popular Topics Like Government, Sports, Medicine, Fintech, Food, More. Flexible Data Ingestion." />\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0">\r\n  <meta name="theme-color" content="#008ABC" />\r\n  <script nonce="qzX0PEkHKrRBSLMW4TeaQA==" type="text/javascript">\r\n    window["pageRequestStartTime"] = 1771406175915;\r\n    window["pageRequestEndTime"] = 1771406175918;\r\n    window["initialPageLoadStartTime"] = new Date().getTime();\r\n  </script>\r\n  <script nonce="qzX0PEkHKrRBSLMW4TeaQA==" id="gsi-client" src="https://accounts.google.com/gsi/client" async defer></
# ...

# %% [markdown]
# # exercise 4

# %%
import os  
os.getcwd()
# Out:
# '/Users/nimeshikamadushani/Desktop/lec/Madushani/day 3'

# %% [markdown]
# # CSV Library

# %%
import csv

with open("my_data.csv") as f:
    reader= csv.reader (f)
    for row in reader:
        print(row)
# Out:
# ['id', 'name', 'age', 'city']
# ['1', 'alice', '34', 'new york']
# ['2', 'bob', '23', 'los angeles']
# ['3', 'charlie', '40', 'chicage']
# ['4', 'diana', '28', 'houston']
# ['5', 'evan', '35', 'phoneix']

# %%
import csv

with open("my_data.csv") as f:
    reader= csv.DictReader (f)
    for row in reader:
        print(row["name"])
# Out:
# 1
# 2
# 3
# 4
# 5
